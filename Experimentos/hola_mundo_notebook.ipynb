# %%
print("Hola mundo")
# Out:
# Hola mundo

# %%
nombre = "Liliana"
anio_actual = 2026
anio_nacimiento = 1986

# %%
edad = anio_actual - anio_nacimiento
print("Hola,", nombre)
print("Tengo", edad, "años")
# Out:
# Hola, Liliana
# Tengo 40 años
